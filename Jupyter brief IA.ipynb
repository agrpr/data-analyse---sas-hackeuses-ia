# %%
import pandas as pd

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.4
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#first dataframe creation

data_web = pd.read_excel("C:/Users/Simplon/Documents/brief IA yannick/web.xlsx")
print(data_web)
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
#second dataframe creation

data_liaison = pd.read_excel("C:/Users/Simplon/Documents/brief IA yannick/liaison.xlsx")
print(data_liaison)
# Out:
#      product_id   id_web
# 0          3847    15298
# 1          3849    15296
# 2          3850    15300
# 3          4032    19814
# 4          4039    19815
# ..          ...      ...
# 820        7203      NaN
# 821        7204      NaN
# 822        7247  13127-1
# 823        7329  14680-1
# 824        7338    16230
#
# [825 rows x 2 columns]
# C:\Users\Simplon\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#third dataframe creation

data_erp = pd.read_excel("C:/Users/Simplon/Documents/brief IA yannick/erp.xlsx")
print(data_erp)
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status
# 0          3847           1   24.2               0   outofstock
# 1          3849           1   34.3               0   outofstock
# 2          3850           1   20.8               0   outofstock
# 3          4032           1   14.1               0   outofstock
# 4          4039           1   46.0               0   outofstock
# ..          ...         ...    ...             ...          ...
# 820        7203           0   45.0              30      instock
# 821        7204           0   45.0               9      instock
# 822        7247           1   54.8              23      instock
# 823        7329           0   26.5              14      instock
# 824        7338           1   16.3              45      instock
#
# [825 rows x 5 columns]
# C:\Users\Simplon\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#drop duplicates in my first dataframe

data_web.drop_duplicates(keep = 'first' ,inplace=True)
print(data_web)
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# ...

# %%
#drop duplicates in my second dataframe

data_liaison.drop_duplicates(keep = 'first' ,inplace=True)
print(data_liaison)
# Out:
#      product_id   id_web
# 0          3847    15298
# 1          3849    15296
# 2          3850    15300
# 3          4032    19814
# 4          4039    19815
# ..          ...      ...
# 820        7203      NaN
# 821        7204      NaN
# 822        7247  13127-1
# 823        7329  14680-1
# 824        7338    16230
#
# [825 rows x 2 columns]

# %%
#drop duplicates in my third dataframe

data_erp.drop_duplicates(keep = 'first' ,inplace=True)
print(data_erp)
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status
# 0          3847           1   24.2               0   outofstock
# 1          3849           1   34.3               0   outofstock
# 2          3850           1   20.8               0   outofstock
# 3          4032           1   14.1               0   outofstock
# 4          4039           1   46.0               0   outofstock
# ..          ...         ...    ...             ...          ...
# 820        7203           0   45.0              30      instock
# 821        7204           0   45.0               9      instock
# 822        7247           1   54.8              23      instock
# 823        7329           0   26.5              14      instock
# 824        7338           1   16.3              45      instock
#
# [825 rows x 5 columns]

# %%
#show null column in my first dataframe

data_web.isnull().sum()
# Out:
# sku                         3
# virtual                     0
# downloadable                0
# rating_count                0
# average_rating              1
# total_sales                 1
# tax_status                715
# tax_class                1431
# post_author                 1
# post_date                   1
# post_date_gmt               1
# post_content             1431
# post_title                  1
# post_excerpt              715
# post_status                 1
# comment_status              1
# ping_status                 1
# post_password            1431
# post_name                   1
# post_modified               1
# post_modified_gmt           1
# post_content_filtered    1431
# post_parent                 1
# guid                        1
# menu_order                  1
# post_type                   1
# post_mime_type            717
# comment_count               1
# dtype: int64

# %%
#show null column in my second dataframe

data_liaison.isnull().sum()
# Out:
# product_id     0
# id_web        91
# dtype: int64

# %%
#show null column in my third dataframe

data_erp.isnull().sum()
# Out:
# product_id        0
# onsale_web        0
# price             0
# stock_quantity    0
# stock_status      0
# dtype: int64

# %%
data_web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1431 entries, 0 to 1512
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    1428 non-null   object
#  1   virtual                1431 non-null   int64
#  2   downloadable           1431 non-null   int64
#  3   rating_count           1431 non-null   int64
#  4   average_rating         1430 non-null   float64
#  5   total_sales            1430 non-null   float64
#  6   tax_status             716 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            1430 non-null   float64
#  9   post_date              1430 non-null   datetime64[ns]
#  10  post_date_gmt          1430 non-null   datetime64[ns]
#  11  post_content           0 non-null      float64
#  12  post_title             1430 non-null   object
#  13  post_excerpt           716 non-null    object
# ...

# %%
#create new dataframe(df) with merging second and third dataframe

df = pd.merge(data_erp, data_liaison, how='outer')
print(df)
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status   id_web
# 0          3847           1   24.2               0   outofstock    15298
# 1          3849           1   34.3               0   outofstock    15296
# 2          3850           1   20.8               0   outofstock    15300
# 3          4032           1   14.1               0   outofstock    19814
# 4          4039           1   46.0               0   outofstock    19815
# ..          ...         ...    ...             ...          ...      ...
# 820        7203           0   45.0              30      instock      NaN
# 821        7204           0   45.0               9      instock      NaN
# 822        7247           1   54.8              23      instock  13127-1
# 823        7329           0   26.5              14      instock  14680-1
# 824        7338           1   16.3              45      instock    16230
#
# [825 rows x 6 columns]

# %%
df[df['product_id']==4352]
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status id_web
# 208        4352           1  225.0               0   outofstock  15940

# %%
#new dataframe (data_web2) without blank column, in order to merge

data_web2 = data_web.dropna(axis=1, how = 'all')
print(data_web2)
# Out:
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  post_author           post_date  \
# 0                0.0         10.0    taxable          1.0 2018-06-01 13:53:46
# ...

# %%
#new dataframe (df2) with renamed column, in order to merge

df2 = data_web2.rename(columns = {'sku':'id_web'})
print(df2)
# Out:
#                    id_web  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
#       average_rating  total_sales tax_status  post_author           post_date  \
# 0                0.0         10.0    taxable          1.0 2018-06-01 13:53:46
# ...

# %%
#creation of a new dataframe(df3) with merging df and df2 

df3 = pd.merge(df, df2, how='outer')
print(df3)
# Out:
#       product_id  onsale_web  price  stock_quantity stock_status   id_web  \
# 0           3847           1   24.2               0   outofstock    15298
# 1           3847           1   24.2               0   outofstock    15298
# 2           3849           1   34.3               0   outofstock    15296
# 3           3849           1   34.3               0   outofstock    15296
# 4           3850           1   20.8               0   outofstock    15300
# ...          ...         ...    ...             ...          ...      ...
# 1716        7247           1   54.8              23      instock  13127-1
# 1717        7247           1   54.8              23      instock  13127-1
# 1718        7329           0   26.5              14      instock  14680-1
# 1719        7338           1   16.3              45      instock    16230
# 1720        7338           1   16.3              45      instock    16230
#
#       virtual  downloadable  rating_count  average_rating  ...  ping_status  \
# ...

# %%
df3[df3['product_id']==4352]
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status id_web  \
# 672        4352           1  225.0               0   outofstock  15940
# 673        4352           1  225.0               0   outofstock  15940
#
#      virtual  downloadable  rating_count  average_rating  ...  ping_status  \
# 672      0.0           0.0           0.0             0.0  ...       closed
# 673      0.0           0.0           0.0             0.0  ...       closed
#
#                                           post_name       post_modified  \
# 672  champagne-egly-ouriet-grand-cru-millesime-2008 2020-03-07 11:18:45
# 673  champagne-egly-ouriet-grand-cru-millesime-2008 2020-03-07 11:18:45
#
#       post_modified_gmt post_parent  \
# 672 2020-03-07 10:18:45         0.0
# 673 2020-03-07 10:18:45         0.0
#
#                                                   guid menu_order   post_type  \
# 672  https://www.wine-spirit.fr/?post_type=product&...        0.0     product
# ...

# %%
#creation of a cleaned dataframe(df4) from df3 

df4 = df3[df3['post_type']=='product']
print(df4)
# Out:
#       product_id  onsale_web  price  stock_quantity stock_status   id_web  \
# 0           3847           1   24.2               0   outofstock    15298
# 2           3849           1   34.3               0   outofstock    15296
# 4           3850           1   20.8               0   outofstock    15300
# 6           4032           1   14.1               0   outofstock    19814
# 8           4039           1   46.0               0   outofstock    19815
# ...          ...         ...    ...             ...          ...      ...
# 1710        6930           1    8.4              83      instock    16135
# 1712        7023           1   27.5              15      instock    15891
# 1714        7025           1   69.0               2      instock    15887
# 1716        7247           1   54.8              23      instock  13127-1
# 1719        7338           1   16.3              45      instock    16230
#
#       virtual  downloadable  rating_count  average_rating  ...  ping_status  \
# ...

# %%
#creation of a "total_sales for each product" dataframe

df_total_sales_product = df4["price"] * df4["total_sales"]
print(df_total_sales_product)
# Out:
# 0       145.2
# 2         0.0
# 4         0.0
# 6        42.3
# 8         0.0
#         ...
# 1710     42.0
# 1712      0.0
# 1714      0.0
# 1716      0.0
# 1719      0.0
# Length: 896, dtype: float64

# %%
#total dataframe

total = df_total_sales_product.sum()
print(total)
# Out:
# 70568.6

# %%
import seaborn as sns

# %%
sns.boxplot(df4.price)
# Out:
# C:\Users\Simplon\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
df4.describe()
# Out:
#         product_id  onsale_web       price  stock_quantity  virtual  \
# count   896.000000  896.000000  896.000000       896.00000    896.0
# mean   5256.787946    0.803571   32.803013        25.84933      0.0
# std     977.611587    0.397518   26.401321        44.80349      0.0
# min    3847.000000    0.000000    5.200000         0.00000      0.0
# 25%    4391.750000    1.000000   15.300000         1.00000      0.0
# 50%    4927.500000    1.000000   25.900000        11.00000      0.0
# 75%    5917.250000    1.000000   42.700000        33.00000      0.0
# max    7338.000000    1.000000  225.000000       578.00000      0.0
#
#        downloadable  rating_count  average_rating  total_sales  post_author  \
# count         896.0         896.0           896.0   896.000000   896.000000
# mean            0.0           0.0             0.0     3.197545     1.998884
# std             0.0           0.0             0.0     7.772609     0.033408
# ...

# %%
#IQR

Q3 = np.quantile(df4['price'], 0.75)
Q1 = np.quantile(df4['price'], 0.25)
IQR = Q3 - Q1
    
print("IQR value for column %s is: %s" % ('price', IQR))
    
lower_range = Q1 - 1.5 * IQR
upper_range = Q3 + 1.5 * IQR
# Out:
# IQR value for column price is: 27.400000000000002

# %%
#show highter abnormal price values

outlier_list = [x for x in df4['price'] if (x > upper_range)]
print(outlier_list)
# Out:
# [86.1, 86.1, 144.0, 144.0, 84.7, 84.7, 92.0, 92.0, 100.0, 88.4, 225.0, 126.5, 85.6, 176.0, 108.5, 157.0, 104.0, 109.6, 102.3, 137.0, 217.5, 105.0, 105.0, 112.0, 86.8, 92.0, 124.8, 175.0, 191.3, 93.0, 122.0, 114.0, 135.0, 105.6, 116.4, 115.0, 121.0, 99.0, 115.0, 121.0]

# %%
#show highter abnormal price values in a graphic

from matplotlib import pyplot as plt

x = [86.1, 86.1, 144.0, 144.0, 84.7, 84.7, 92.0, 92.0, 100.0, 88.4, 225.0, 126.5, 85.6, 176.0, 108.5, 157.0, 104.0, 109.6, 102.3, 137.0, 217.5, 105.0, 105.0, 112.0, 86.8, 92.0, 124.8, 175.0, 191.3, 93.0, 122.0, 114.0, 135.0, 105.6, 116.4, 115.0, 121.0, 99.0, 115.0, 121.0]
y = [ i*i for i in x]


plt.plot(x,y)
plt.show()

# %%
#show highter abnormal price products

b = df4.loc[df4['price'] > upper_range]
b
# Out:
#       product_id  onsale_web  price  stock_quantity stock_status id_web  \
# 39          4055           0   86.1               0   outofstock    NaN
# 40          4055           0   86.1               0   outofstock    NaN
# 72          4594           1  144.0               0   outofstock    NaN
# 73          4594           1  144.0               0   outofstock    NaN
# 123         5070           1   84.7               0   outofstock    NaN
# 124         5070           1   84.7               0   outofstock    NaN
# 147         6324           0   92.0              18      instock    NaN
# 148         6324           0   92.0              18      instock    NaN
# 399         4115           1  100.0              11      instock  15382
# 403         4132           1   88.4               5      instock  11668
# 672         4352           1  225.0               0   outofstock  15940
# 676         4355           1  126.5               2      instock  12589
# ...

# %%
#show price/total sales quantity graphic

df4.plot(x='total_sales', y='price', style='o')
plt.title('sales')
plt.xlabel('total_sales quantity')
plt.ylabel('price in euros')
plt.show()

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn as sk
from sklearn import preprocessing, svm 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
#train my model

x = np.array(df4['total_sales']).reshape(-1, 1) 
y = np.array(df4['price']).reshape(-1, 1) 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 4)
regr = LinearRegression() 

regr.fit(x_train, y_train) 
print(regr.score(x_test, y_test))
# Out:
# -0.051897872852724625

# %%
#show linear regression

y_pred = regr.predict(x_test) 
plt.scatter(x_test, y_test, color ='b') 
plt.plot(x_test, y_pred, color ='k') 
  
plt.show()

# %%
# Calculate the z-score from with scipy

import scipy.stats as stats

df4['z_score']= stats.zscore(df4[['price']])
df4[df4['z_score']>2]
# Out:
# C:\Users\Simplon\AppData\Local\Temp/ipykernel_5416/1425221427.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['z_score']= stats.zscore(df4[['price']])
#       product_id  onsale_web  price  stock_quantity stock_status id_web  \
# 39          4055           0   86.1               0   outofstock    NaN
# 40          4055           0   86.1               0   outofstock    NaN
# 72          4594           1  144.0               0   outofstock    NaN
# 73          4594           1  144.0               0   outofstock    NaN
# 147         6324           0   92.0              18      instock    NaN
# 148         6324           0   92.0              18      instock    NaN
# ...

# %%
outliers = (df4['price']> upper_range)

df4['color']= np.where( value==True , "red", "blue")

plt.scatter(df4.total_sales, df4.price, color= df4.color)
plt.plot(x_test, y_pred, color = 'k')


plt.show()
# Out:
# C:\Users\Simplon\AppData\Local\Temp/ipykernel_5416/3007369106.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['color']= np.where( value==True , "red", "blue")
